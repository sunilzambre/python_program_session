# %%
import numpy as np

# %%
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = np.mean(speed)

print("The mean is: ",x)
# Out:
# The mean is:  89.76923076923077

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\admin\anaconda3\lib\site-packages (from scipy) (1.21.5)

# %%
from scipy import stats

mo = [93,76,87,88,111,76,103,87,91,78,77,85,76]

x2 = stats.mode(mo)

print(x)
# Out:
# 89.76923076923077

# %%
import numpy as np
from scipy import stats

# Define the input array
arr = np.array([3, 2, 4, 2, 1, 3, 2, 4, 4, 5, 1])

# Calculate the mean of the array
mean = np.mean(arr)
print("Mean:", mean)

# Calculate the median of the array
median = np.median(arr)
print("Median:", median)

# Calculate the mode of the array
mode = stats.mode(arr)
print("Mode:", mode)
# Out:
# Mean: 2.8181818181818183
# Median: 3.0
# Mode: ModeResult(mode=array([2]), count=array([3]))

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
    return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
import numpy as np
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451027
